# %%
data = pd.read_csv('hidden_atlat_exp1.csv')
# data = data[data['variant'] != 'control']
exp_cfg = {
  'alpha': 0.05,
  'beta': 0.2 ,
  'exp_name': 'asasdas',
  'test_method': 'Sequencial',
  'control_variant': 'control',
  'list_metrics': ['Session_Duration', 'Session_Count' ],
  'primary_metric': 'Session_Count',
  'mde': 0.1,
    'expected_precision': 0.05,
  'weight_traffic' :  {
  'control' : 0.04  ,
  'treatment_1' : 0.48  ,
  'treatment_2' : 0.48  ,
  }


}

# %%
exp = Experiment(data = data , exp_cfg = exp_cfg)

# %%
exp.main()
# Out:
# 2023-12-04 10:30:32 AM: primary metric is calculated Session_Count
# 2023-12-04 10:30:32 AM: run test with 1955 rows
# 2023-12-04 10:30:32 AM: estimate_sample_size: 1178.6173649967388
# 2023-12-04 10:30:32 AM: Statistical test suite analysis with 2 tests, testmethod group_sequential, correction method CorrectionMethod.BH has just started
# 2023-12-04 10:30:32 AM: Information fraction is 0.8306342915647682
# 2023-12-04 10:30:32 AM: alpha_new is 0.03151423211739379
# 2023-12-04 10:30:32 AM: z is 0.37032063431292805
# 2023-12-04 10:30:32 AM: bound is 2.150518400336033
# 2023-12-04 10:30:32 AM: Information fraction is 0.8204528702177026
# 2023-12-04 10:30:32 AM: alpha_new is 0.03047811261373301
# 2023-12-04 10:30:32 AM: z is 0.30459576926990223
# 2023-12-04 10:30:32 AM: bound is 2.163820702857751
# /opt/airflow/dags/utils/abtest_core/core/statistics.py:328: UserWarning: Sample variances differ too much to assume that population variances are equal.
# ...

# %%
exp.df_final_result
# Out:
#             update_timestamp   exp_id                          metric_id  \
# 0 2023-12-04 10:30:32.373362  asasdas  [Session_Duration, Session_Count]
#
#                                primary_metric_result  \
# 0  {'correction_method': 'BH', 'results': [{'resu...
#
#       list_secondary_metric_result_before_correction  \
# 0  [{'correction_method': 'BH', 'results': [{'res...
#
#        list_secondary_metric_result_after_correction
# 0  [{'correction_method': 'NONE', 'results': [{'r...
